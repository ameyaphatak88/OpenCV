# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

image1 = cv2.imread('ameya.jpeg')
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

plt.imshow(image1)

# %%
gray_img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_img)

# %%
hsv_img = cv2.cvtColor(image1, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsv_img)

# %%
ret,thresh_binary = cv2.threshold(image1,127,255,cv2.THRESH_BINARY)

# %%
plt.imshow(thresh_binary, 'gray')

# %%
ret,thresh_trunc = cv2.threshold(image1,200,255,cv2.THRESH_TRUNC)

# %%
plt.imshow(thresh_trunc, 'gray')

# %%
edges = cv2.Canny(image1,100,200)

# %%
plt.imshow(edges)

# %%
import cv2 as cv

# %%
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('haarcascade_eye.xml')

# %%
gray = cv.cvtColor(image1, cv2.COLOR_BGR2GRAY)

# %%
import numpy as np

# %%
averaging_kernel = np.ones((3,3),np.float32)/9

# %%
filtered_image = cv2.filter2D(image1,-1,averaging_kernel)

# %%
plt.imshow(filtered_image)

# %%
gaussian_kernel_x = cv2.getGaussianKernel(5,1) 
gaussian_kernel_y = cv2.getGaussianKernel(5,1)

# %%
gaussian_kernel = gaussian_kernel_x * gaussian_kernel_y.T

# %%
filtered_image = cv2.filter2D(image1,-1,gaussian_kernel)

# %%
plt.imshow(filtered_image)

# %% [markdown]
# ## FACE DETECTION

# %%
import os
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
img = cv.imread('ameya.jpeg',0)

# %%
plt.imshow(img)

# %%
faces = face_cascade.detectMultiScale(img, 1.1, 4)

# %%
for(x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(img)
